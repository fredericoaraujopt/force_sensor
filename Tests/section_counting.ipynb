# %%
import os
from pathlib import Path
from ideal_peakfinder import plot_peaks
from plotting import plot_peaks_overlay
package_path = Path(os.path.abspath("")).parent
data_path = package_path / "Data"

# DULL KNIFE EPON TISSUE
experiment_9 = data_path / "Experiment 9/20250309_1505/Analog - 3-9-2025 3-19-47.163 PM.csv" # epon tissue 30 sections 250 nm 0.08mm/s
experiment_10 = data_path / "Experiment 10/20250309_1610/Analog - 3-9-2025 4-10-31.437 PM.csv" # epon tissue 20 sections 500 nm 0.08mm/s
experiment_11 = data_path / "Experiment 11/20250309_1657/Analog - 3-9-2025 4-57-23.636 PM.csv" # epon tissue 30 sections 250 nm 0.4 mm/s
experiment_12 = data_path / "Experiment 12/20250309_1733/Analog - 3-9-2025 5-33-01.430 PM.csv" # epon tissue 30 sections 500 nm 0.4 mm/s
# DULL KNIFE LX112 TISSUE
experiment_13 = data_path / "Experiment 13/20250309_1820/Analog - 3-9-2025 6-20-50.495 PM.csv" # lx112 tissue 20 sections 250 nm 0.08 mm/s
experiment_14 = data_path / "Experiment 14/20250309_2228/Analog - 3-9-2025 10-28-41.486 PM.csv" # lx112 tissue 30 sections 250 nm 0.4 mm/s
experiment_15 = data_path / "Experiment 15/20250309_2250/Analog - 3-9-2025 10-50-54.082 PM.csv" # lx112 tissue 30 sections 500 nm 0.4 mm/s
experiment_18 = data_path / "Experiment 18/20250311_1512/Analog - 3-11-2025 3-25-12.405 PM.csv" # lx112 tissue 20 sections 500 nm 0.08 mm/s
# SHARP KNIFE LX112 TISSUE
experiment_20 = data_path / "Experiment 20/20250311_1731/Analog - 3-11-2025 5-35-04.424 PM.csv" # lx112 tissue 20 sections 500 nm 0.08 mm/s
experiment_21 = data_path / "Experiment 21/20250311_1821/Analog - 3-11-2025 6-23-53.659 PM.csv" # lx112 tissue 20 sections 250 nm 0.08 mm/s
experiment_22 = data_path / "Experiment 22/20250311_2141/Analog - 3-11-2025 9-41-14.577 PM.csv" # lx112 tissue 30 sections 250 nm 0.4 mm/s
experiment_23 = data_path / "Experiment 23/20250311_2204/Analog - 3-11-2025 10-04-50.289 PM.csv" # lx112 tissue 30 sections 500 nm 0.4 mm/s
# SHARP KNIFE EPON TISSUE
experiment_24 = data_path / "Experiment 24/20250311_2245/Analog - 3-11-2025 10-45-49.556 PM.csv" # epon tissue 20 sections 250 nm 0.08 mm/s
experiment_25 = data_path / "Experiment 25/20250311_2329/Analog - 3-11-2025 11-29-22.062 PM.csv" # epon tissue 20 sections 500 nm 0.08 mm/s
experiment_26 = data_path / "Experiment 26/20250312_0012/Analog - 3-12-2025 12-12-39.849 AM.csv" # epon tissue 30 sections 250 nm 0.4 mm/s
experiment_27 = data_path / "Experiment 27/20250312_0034/Analog - 3-12-2025 12-34-03.110 AM.csv" # epon tissue 30 sections 500 nm 0.4 mm/s

# %%
# DULL KNIFE EPON TISSUE
labels_dull_epon = ["250 nm 0.08mm/s", "500 nm 0.08mm/s", "250 nm 0.4 mm/s", "500 nm 0.4 mm/s"]
experiments_dull_epon = [experiment_9, experiment_10, experiment_11, experiment_12]
peaks = []

for experiment, label in zip(experiments_dull_epon, labels_dull_epon):
    result = plot_peaks(experiment, derivative=True, frequency_domain=True, label=label)
    peaks.append(result)

results_dull_epon = plot_peaks_overlay(experiments_dull_epon, peaks, labels=labels_dull_epon)
# Out:
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 15.00 Hz
# Top 5 values of inverted signal (for threshold estimation): [13.56754735 13.49938693 13.49429397 13.48419109 13.47586275]
# Selected reference peak (index 16): 13.33519
# Height Threshold (35% of reference peak): 4.66732
# Initial Peak Count: 20
# New Distance: 63.46 seconds
# Final Peak Count: 20
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 15.00 Hz
# Top 5 values of inverted signal (for threshold estimation): [36.24806789 36.20996314 35.89073424 35.76542707 35.16036978]
# Selected reference peak (index 16): 25.24204
# Height Threshold (35% of reference peak): 8.83471
# Initial Peak Count: 22
# New Distance: 63.00 seconds
# Final Peak Count: 21
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 9.96 Hz
# ...

# %%
# DULL KNIFE LX112 TISSUE
labels_dull_lx112 = ["250 nm 0.08mm/s", "250 nm 0.4mm/s", "500 nm 0.4 mm/s", "500 nm 0.08 mm/s"]
experiments_dull_lx112 = [experiment_13, experiment_14, experiment_15, experiment_18]
peaks = []

for experiment, label in zip(experiments_dull_lx112, labels_dull_lx112):
    result = plot_peaks(experiment, derivative=True, frequency_domain=True, label=label)
    peaks.append(result)

fragments = plot_peaks_overlay(experiments_dull_lx112, peaks, labels=labels_dull_lx112)
# Out:
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 15.00 Hz
# Top 5 values of inverted signal (for threshold estimation): [11.58508499 11.55719401 11.48639876 11.40030727 11.39633254]
# Selected reference peak (index 16): 11.20373
# Height Threshold (35% of reference peak): 3.92131
# Initial Peak Count: 20
# New Distance: 67.31 seconds
# Final Peak Count: 19
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 6.46 Hz
# Top 5 values of inverted signal (for threshold estimation): [4.98383573 4.98252517 4.98143147 4.977937   4.97154718]
# Selected reference peak (index 16): 4.85912
# Height Threshold (35% of reference peak): 1.70069
# Initial Peak Count: 31
# New Distance: 15.68 seconds
# Final Peak Count: 30
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 2.95 Hz
# ...

# %%
# SHARP KNIFE LX112 TISSUE
labels_sharp_lx112 = ["500 nm 0.08mm/s", "250 nm 0.08 mm/s", "250 nm 0.4 mm/s", "500 nm 0.4 mm/s"]
experiments_sharp_lx112 = [experiment_20, experiment_21, experiment_22, experiment_23]
peaks = []

for experiment, label in zip(experiments_sharp_lx112, labels_sharp_lx112):
    result = plot_peaks(experiment, derivative=True, frequency_domain=True, label=label)
    peaks.append(result)

plot_peaks_overlay(experiments_sharp_lx112, peaks, labels=labels_sharp_lx112)
# Out:
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 15.00 Hz
# Top 5 values of inverted signal (for threshold estimation): [12.45989825 12.43340746 12.35007379 12.33391238 12.32313368]
# Selected reference peak (index 16): 12.14819
# Height Threshold (35% of reference peak): 4.25187
# Initial Peak Count: 17
# New Distance: 73.91 seconds
# Final Peak Count: 17
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 15.00 Hz
# Top 5 values of inverted signal (for threshold estimation): [12.33347185 12.30151315 12.2893108  12.28573598 12.25002748]
# Selected reference peak (index 16): 12.18168
# Height Threshold (35% of reference peak): 4.26359
# Initial Peak Count: 18
# New Distance: 73.92 seconds
# Final Peak Count: 18
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 7.72 Hz
# ...

# %%
# SHARP KNIFE EPON TISSUE
labels_sharp_epon = ["250 nm 0.08mm/s", "500 nm 0.08 mm/s", "250 nm 0.4 mm/s", "500 nm 0.4 mm/s"]
experiments_sharp_epon = [experiment_24, experiment_25, experiment_26, experiment_27]
peaks = []

for experiment, label in zip(experiments_sharp_epon, labels_sharp_epon):
    result = plot_peaks(experiment, derivative=True, frequency_domain=True, label=label)
    peaks.append(result)

results_sharp_epon = plot_peaks_overlay(experiments_sharp_epon, peaks, labels=labels_sharp_epon)
# Out:
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 15.00 Hz
# Top 5 values of inverted signal (for threshold estimation): [13.53216209 13.50115939 13.49169189 13.46573846 13.46454587]
# Selected reference peak (index 16): 13.33524
# Height Threshold (35% of reference peak): 4.66733
# Initial Peak Count: 20
# New Distance: 66.23 seconds
# Final Peak Count: 20
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 15.00 Hz
# Top 5 values of inverted signal (for threshold estimation): [12.76278023 12.71396794 12.69949685 12.69465906 12.67851591]
# Selected reference peak (index 16): 12.53337
# Height Threshold (35% of reference peak): 4.38668
# Initial Peak Count: 20
# New Distance: 66.19 seconds
# Final Peak Count: 20
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 15.00 Hz
# ...

# %%
# COMPARE PLOTS
labels = ["500 nm 0.4mm/s epon old knife", "500 nm 0.4mm/s epon new knife"]
experiments = [experiment_12, experiment_27]
peaks = []

for experiment, label in zip(experiments, labels):
    result = plot_peaks(experiment, derivative=True, frequency_domain=True, label=label)
    peaks.append(result)

results = plot_peaks_overlay(experiments, peaks, labels=labels)
# Out:
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 3.13 Hz
# Top 5 values of inverted signal (for threshold estimation): [3.75046598 3.75017776 3.74755636 3.74668964 3.74145483]
# Selected reference peak (index 16): 3.63863
# Height Threshold (35% of reference peak): 1.27352
# Initial Peak Count: 30
# New Distance: 15.47 seconds
# Final Peak Count: 29
# Extracted frequency from metadata: 500 Hz
# Initial Distance: 5.00 seconds
# Estimated cutoff frequency: 3.79 Hz
# Top 5 values of inverted signal (for threshold estimation): [6.67600372 6.67285704 6.67275469 6.6633471  6.66308625]
# Selected reference peak (index 16): 6.57749
# Height Threshold (35% of reference peak): 2.30212
# Initial Peak Count: 30
# New Distance: 16.81 seconds
# Final Peak Count: 30

# %%
from analysis import compare_experiments
output_csv = data_path / "Comparisons/dullvnew_500nm_0.4mms_epon.csv"
# remember that plot_peaks_overlay returns a list,
# [ list_of_fragments, avg_fragment ]

'''snippet1 = results_dull_epon[2][0]  # experiment 11 250 nm 0.4 mm/s dull knife
snippet2 = results_sharp_epon[2][0]  # experiment 24 250 nm 0.4 mm/s sharp knife

snippet3 = results_dull_epon[3][0]  # experiment 12 500 nm 0.4 mm/s dull knife
snippet4 = results_sharp_epon[3][0]  # experiment 27 500 nm 0.4 mm/s sharp knife

snippet5 = results_dull_epon[0][0]  # experiment 9 250 nm 0.08 mm/s dull knife
snippet6 = results_sharp_epon[0][0]  # experiment 24 250 nm 0.08 mm/s sharp knife

snippet7 = results_dull_epon[1][0]  # experiment 10 500 nm 0.08 mm/s dull knife
snippet8 = results_sharp_epon[1][0]  # experiment 25 500 nm 0.08 mm/s sharp knife'''

compare_experiments(experiment_12, results[0][0], experiment_27, results[1][0], output_csv)
# Out:
# Processing fragment 0 with length: 15776
# Fragment 0 metrics: avg=-13.7614, std=76.6821, peak=203.7311, duration=31.5520, chatter=0.0659, slope=17.7033
# Processing fragment 1 with length: 15776
# Fragment 1 metrics: avg=-23.3988, std=78.0858, peak=199.6917, duration=31.5520, chatter=0.0746, slope=34.2643
# Processing fragment 2 with length: 15776
# Fragment 2 metrics: avg=-19.4387, std=77.0541, peak=189.7546, duration=31.5520, chatter=0.0747, slope=19.6138
# Processing fragment 3 with length: 15776
# Fragment 3 metrics: avg=-25.9389, std=81.3166, peak=189.5800, duration=31.5520, chatter=0.0703, slope=25.9663
# Processing fragment 4 with length: 15776
# Fragment 4 metrics: avg=-25.7116, std=76.1905, peak=168.6685, duration=31.5520, chatter=0.0792, slope=22.1256
# Processing fragment 5 with length: 15776
# Fragment 5 metrics: avg=-28.2804, std=79.6961, peak=183.5138, duration=31.5520, chatter=0.0673, slope=18.9407
# Processing fragment 6 with length: 15776
# ...

# %%
from plotting import simulate_real_time_force_plot
simulate_real_time_force_plot(experiment_12, frequency=5000)
# Out:
# 2025-03-26 21:49:44.744 python[23673:8866638] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-26 21:49:44.744 python[23673:8866638] +[IMKInputSession subclass]: chose IMKInputSession_Modern
